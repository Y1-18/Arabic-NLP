# %%
from datasets import load_dataset

ds = load_dataset("arbml/SaudiIrony")
# Out:
# README.md:   0%|          | 0.00/431 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# dataset_infos.json: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/1.61M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/19804 [00:00<?, ? examples/s]

# %%
import torch
from torch import nn
from torch.nn import functional as F
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import time

# %%
data = [ds['train']['Tweet'][i] for i in range(len(ds['train']['Tweet']))]

# %%
vocab= sorted(list(set(' '.join(data).split())))
vocab
# Out:
# ['#ERROR!',
#  '%',
#  '%شئ',
#  '%مززح',
#  '&',
#  '&اغلب',
#  '&مسانده',
#  '*',
#  '**',
#  '*~♔˛⁽',
#  '*اكثر',
#  '*الشاعر*',
#  '*العظمه',
#  '*اللهم',
#  '*انا',
#  '*انزه',
#  '*اول',
#  '*زباله',
#  '*شدعوه',
#  '*صباح',
#  '*قومي',
#  '*كنت',
#  '*كوميديا',
#  '*لئن',
#  '*لا',
#  '*لاتدع',
#  '*لقد',
#  '*للي',
#  '*مع',
#  '*＊✿❀',
#  '+',
#  '++',
#  '+ادري',
#  '+ترا',
#  '+شاطر',
#  '+قاعدين',
#  '+مصورتها',
#  '+هو',
#  '+وفي',
#  ',',
#  ',,',
#  ',احب',
#  ',بس',
#  ',بعدين',
#  ':1st_place_medal::thumbsup::ok_hand::ok_hand::heart:',
#  ':algeria::algeria:لانه',
#  ':alien:',
#  ':alien::alien:',
#  ':angel:🏻',
#  ':angry:عندنا',
#  ':angry:ولا',
#  ':anguished:',
#  ':apple::green_heart::apple:',
#  ':arrow_down:',
#  ':arrow_down::arrow_down::arrow_down:',
#  ':arrow_heading_down:',
#  ':arrow_heading_down::arrow_heading_down:',
#  ':articulated_lorry:',
#  ':asterisk:',
#  ':astonished:',
#  ':astonished::astonished:',
#  ':astonished::roll_eyes:',
#  ':astonished::roll_eyes:لا',
#  ':austria::austria::austria::austria::austria::austria::austria::austria::austria:',
#  ':baby_bottle:',
#  ':baby_bottle::revolving_hearts::pleading_face:',
#  ':bahrain:',
#  ':balance_scale::mortar_board::hearts::sparkles:',
#  ':balloon::confetti_ball::heart:',
#  ':bangbang:',
#  ':bangbang:☝',
#  ':bar_chart:',
#  ':black_flag::black_flag:',
#  ':black_heart:',
#  ':black_heart::black_heart:',
#  ':black_heart::maple_leaf:',
#  ':black_heart::orange_heart::orange_heart:',
#  ':blossom:',
#  ':blossom::blossom:',
#  ':blossom::blossom:fdfd',
#  ':blossom::blossom:اييشش',
#  ':blossom::broken_heart:',
#  ':blossom::hibiscus:',
#  ':blue_heart:',
#  ':blue_heart::blue_heart:',
#  ':blue_heart::blue_heart::clap::clap:',
#  ':blue_heart::blue_heart::fire::fire:',
#  ':blue_heart::blue_heart::heart::saudi_arabia::heart_eyes::muscle::joy::upside_down_face::ok_hand::pray::pray:',
#  ':blue_heart::blue_heart::heart_eyes:',
#  ':blue_heart::blue_heart::rose::rose::blue_heart::blue_heart:',
#  ':blue_heart::blue_heart::sob::sob::pray::pray:',
#  ':blue_heart::blue_heart::trophy::saudi_arabia:',
#  ':blue_heart::blue_heart:fd:blue_heart::blue_heart:fd:blue_heart::blue_heart:fd:blue_heart::blue_heart:',
#  ':blue_heart::blue_heart:يارب',
#  ':blue_heart::fire:',
#  ':blue_heart::heart:',
#  ':blue_heart::ok_hand:',
#  ':blue_heart::pray:',
#  ':blue_heart::relieved:',
#  ':blue_heart::wilted_flower::blue_heart:',
#  ':blue_heart::yellow_heart:',
#  ':blue_heart::yellow_heart::blue_heart:',
#  ':blue_heart::yellow_heart::blue_heart::yellow_heart:',
#  ':blue_heart:fd',
#  ':blue_heart:fd:blue_heart:',
#  ':blue_heart:fd:blue_heart:fd',
#  ':blue_heart:القادم',
#  ':blush:',
#  ':blush::blush:',
#  ':blush::blush::hearts::hearts::hearts::hearts::hearts::hearts::hearts:',
#  ':blush::clap:🏿',
#  ':blush::hugs:',
#  ':blush::ok_hand:',
#  ':blush::pray::rose:',
#  ':blush:f',
#  ':books::hearts:',
#  ':bouquet:',
#  ':bouquet::bouquet:',
#  ':bouquet::pray:',
#  ':bouquet:صباح',
#  ':bow:🏻ud:female_sign::heart_eyes:',
#  ':bow:🏻ud:female_sign::joy:',
#  ':boy:🏻',
#  ':bread:',
#  ':briefcase:',
#  ':broken_heart:',
#  ':broken_heart::blue_heart::blue_heart:',
#  ':broken_heart::broken_heart:',
#  ':broken_heart::broken_heart::joy::joy:',
#  ':broken_heart::broken_heart::sob:',
#  ':broken_heart::cry:',
#  ':broken_heart::expressionless:',
#  ':broken_heart::green_heart:',
#  ':broken_heart::joy:',
#  ':broken_heart::joy::satisfied:',
#  ':broken_heart::new_moon_with_face:',
#  ':broken_heart::palms_up_together:',
#  ':broken_heart::pensive:',
#  ':broken_heart::pleading_face:',
#  ':broken_heart::rofl::rofl:',
#  ':broken_heart::roll_eyes:',
#  ':broken_heart::roll_eyes::new_moon_with_face:لن',
#  ':broken_heart::slightly_smiling_face:',
#  ':broken_heart:f',
#  ':broken_heart:fa',
#  ':broken_heart:بس',
#  ':broken_heart:متسابقينهم',
#  ':broken_heart:ويحسبني',
#  ':bulb::man:🏽udfaf',
#  ':burrito:',
#  ':butterfly::butterfly:',
#  ':call_me_hand:🏻',
#  ':call_me_hand:🏻:call_me_hand:🏻:call_me_hand:🏻:call_me_hand:🏻:call_me_hand:🏻:call_me_hand:🏻:call_me_hand:🏻:call_me_hand:🏻',
#  ':call_me_hand:🏼:call_me_hand:🏼',
#  ':camera:',
#  ':candy:',
#  ':canned_food:',
#  ':cd::musical_note:',
#  ':chart::chart:',
#  ':cherry_blossom:',
#  ':cherry_blossom::cherry_blossom:',
#  ':cherry_blossom::cherry_blossom::blue_heart:',
#  ':cherry_blossom::cherry_blossom:fd',
#  ':cherry_blossom::heartpulse:',
#  ':cherry_blossom::hibiscus:',
#  ':cherry_blossom:🕊',
#  ':child:🏻',
#  ':clap:',
#  ':clap::clap:',
#  ':clap::rose:',
#  ':clap:🏻',
#  ':clap:🏻:blue_heart::blue_heart:',
#  ':clap:🏻:clap:🏻',
#  ':clap:🏻fd',
#  ':clap:🏽:heart:',
#  ':clapper:…',
#  ':clown_face:',
#  ':clown_face::clown_face:',
#  ':clown_face::joy::joy:',
#  ':coffee:',
#  ':coffee::coffee:',
#  ':coffin::coffin::coffin:',
#  ':cold_face:',
#  ':cold_face::cowboy_hat_face:',
#  ':cold_sweat:',
#  ':collision:',
#  ':comet:',
#  ':confounded:',
#  ':confused:',
#  ':confused::confused:',
#  ':confused:اقولك',
#  ':cookie:zahraa’s',
#  ':corn:',
#  ':cow2:',
#  ':cowboy_hat_face:',
#  ':crossed_swords:',
#  ':crown:',
#  ':crown::sparkles:',
#  ':cry:',
#  ':cry::broken_heart:',
#  ':cry::broken_heart::joy:',
#  ':cry::cry:',
#  ':cry::smiling_face_with_three_hearts:',
#  ':cupid:',
#  ':cupid::cupid:هه',
#  ':cursing_face::cursing_face:',
#  ':cursing_face::cursing_face::pout:',
#  ':cut_of_meat:',
#  ':cyclone::cyclone:',
#  ':dancer:',
#  ':dancer::dancer:',
#  ':dancer::rofl:',
#  ':dancer:🏻:dancer:🏻:man_dancing:🏻:dancer:🏻',
#  ':dancers:ud:female_sign::green_heart::green_heart:',
#  ':diamonds:مايبكيني',
#  ':disappointed:',
#  ':disappointed::disappointed:',
#  ':disappointed::disappointed::pleading_face::revolving_hearts::revolving_hearts:الحمدلله',
#  ':disappointed::fist:',
#  ':disappointed_relieved:',
#  ':disappointed_relieved::disappointed_relieved:خايفن',
#  ':disappointed_relieved:ff',
#  ':disguised_face:',
#  ':dizzy:',
#  ':dizzy_face:',
#  ':dizzy_face::dizzy_face:',
#  ':dizzy_face:ud:dizzy:',
#  ':dog2:',
#  ':dog2:faeمذعور',
#  ':dollar:',
#  ':dove:',
#  ':dove:fd',
#  ':duck:',
#  ':eagle:',
#  ':eagle:شبابه',
#  ':ear_of_rice::dizzy::musical_score:',
#  ':ear_of_rice::raising_hand::bouquet::evergreen_tree:',
#  ':ear_of_rice:🌧',
#  ':egypt:',
#  ':egypt::heart:',
#  ':envelope_with_arrow:',
#  ':es:',
#  ':evergreen_tree:',
#  ':exploding_head:',
#  ':exploding_head::exploding_head:',
#  ':expressionless:',
#  ':expressionless::blush:',
#  ':expressionless::expressionless:',
#  ':expressionless::unamused:',
#  ':expressionless::walking:🏻ud:female_sign:',
#  ':expressionless::walking:🏻ud:male_sign:',
#  ':expressionless::walking:🏼\u200d:female_sign:',
#  ':expressionless:شستفدتي',
#  ':eyes:',
#  ':eyes::fire::fire:',
#  ':eyes::grin::joy:',
#  ':eyes::joy:',
#  ':eyes::joy:يلا',
#  ':eyes::see_no_evil::joy:',
#  ':eyes::see_no_evil::joy:…',
#  ':face_with_head_bandage:',
#  ':face_with_head_bandage::frowning_face:',
#  ':face_with_thermometer:',
#  ':face_with_thermometer::rofl:',
#  ':facepalm:',
#  ':facepalm:ud:female_sign:',
#  ':facepalm:ud:male_sign:',
#  ':facepalm:ud:male_sign::facepalm:ud:male_sign:',
#  ':facepalm:ud:male_sign::joy:',
#  ':facepalm:ud:male_sign:خربن',
#  ':facepalm:🏻:broken_heart:',
#  ':facepalm:🏻ud:female_sign:',
#  ':facepalm:🏻ud:female_sign::facepalm:🏻ud:female_sign:',
#  ':facepalm:🏻ud:male_sign:',
#  ':facepalm:🏻ud:male_sign::joy:',
#  ':facepalm:🏻ud:male_sign::joy::joy:',
#  ':facepalm:🏻\u200d:female_sign:',
#  ':facepalm:🏻\u200d:female_sign::broken_heart::broken_heart:',
#  ':facepalm:🏻\u200d:female_sign::facepalm:🏻\u200d:female_sign::facepalm:🏻\u200d:female_sign:',
#  ':facepalm:🏻\u200d:male_sign:',
#  ':facepalm:🏼ud:female_sign:',
#  ':facepalm:🏼ud:male_sign:',
#  ':facepalm:🏽ud:female_sign:',
#  ':facepalm:🏽ud:male_sign:',
#  ':facepalm:🏾ud:female_sign:',
#  ':fallen_leaf:',
#  ':fallen_leaf:🕊',
#  ':fearful:',
#  ':fire:',
#  ':fire::fire:',
#  ':fire::fire::black_heart::yellow_heart:',
#  ':fire::joy:',
#  ':fire::musical_note::hearts:',
#  ':fist_right:',
#  ':flight_departure:',
#  ':flushed:',
#  ':flushed::flushed:',
#  ':flushed::flushed::joy::joy:',
#  ':flushed::joy:',
#  ':flushed::joy::joy:',
#  ':flushed::sob::fire::fire:',
#  ':flushed::sob::fu:🏿',
#  ':flushed::stuck_out_tongue_closed_eyes::joy:',
#  ':flushed:ياخزياه',
#  ':foot:🏻',
#  ':foot:🏿:fu:🏿',
#  ':footprints::footprints:',
#  ':four_leaf_clover:',
#  ':four_leaf_clover::four_leaf_clover:',
#  ':four_leaf_clover:جمعه',
#  ':frog:',
#  ':frog::frog::joy::joy:',
#  ':frowning_face:',
#  ':frowning_face::frowning_face:',
#  ':frowning_face::joy:fdfd',
#  ':frowning_face::sparkling_heart:',
#  ':frowning_person:ud:female_sign:',
#  ':frowning_person:🏽ud:male_sign:',
#  ':fuelpump:',
#  ':full_moon_with_face:',
#  ':full_moon_with_face::broken_heart:',
#  ':full_moon_with_face::joy::joy:',
#  ':full_moon_with_face::lotus_position:🏻ud:female_sign:',
#  ':full_moon_with_face::ok_hand:🏻',
#  ':full_moon_with_face:هه',
#  ':gem:',
#  ':gem::herb:',
#  ':ghost:',
#  ':ghost::ghost:',
#  ':goat::it:',
#  ':green_heart:',
#  ':green_heart::green_heart:',
#  ':green_heart::green_heart::eagle:',
#  ':green_heart::green_heart::trophy::green_heart::green_heart:',
#  ':green_heart::palm_tree::saudi_arabia:',
#  ':green_heart::pray:',
#  ':green_heart::purple_heart:✈',
#  ':green_heart::raised_hand:',
#  ':green_heart::saudi_arabia:',
#  ':grimacing:',
#  ':grimacing::grimacing:',
#  ':grimacing:f',
#  ':grin:',
#  ':grin::grin:',
#  ':grin::joy:',
#  ':grin::joy:fd:blue_heart:',
#  ':grin::raised_hand:🏼',
#  ':grin::satisfied:',
#  ':grin::sweat_smile:',
#  ':grin::tulip:',
#  ':grin:ليش',
#  ':grin:✌🏻',
#  ':grin:🖐',
#  ':grinning:',
#  ':grinning::rose:',
#  ':grinning::vomiting_face:',
#  ':hand_over_mouth:',
#  ':hand_over_mouth::coffee:️',
#  ':hand_over_mouth::expressionless:ياخزياه',
#  ':hand_over_mouth::grin::rofl::joy:',
#  ':hand_over_mouth::hand_over_mouth:',
#  ':hand_over_mouth::joy:',
#  ':hand_over_mouth::ok_hand:🏻',
#  ':hand_over_mouth::running:ud:female_sign::running:ud:female_sign::running:ud:female_sign::running:ud:female_sign:',
#  ':hand_over_mouth::wink::zany_face:',
#  ':handshake:',
#  ':hear_no_evil:',
#  ':heart:',
#  ':heart:+',
#  ':heart::bahrain:',
#  ':heart::black_heart:',
#  ':heart::blue_heart::soccer::soccer::saudi_arabia::thumbsup::pray::heart_eyes::clap:',
#  ':heart::bouquet:',
#  ':heart::cherry_blossom::leaves:',
#  ':heart::crescent_moon:',
#  ':heart::crown:',
#  ':heart::green_heart::rose::smiling_face_with_three_hearts::heart_eyes:',
#  ':heart::handshake:فالبدايه',
#  ':heart::heart:',
#  ':heart::heart::blue_heart::blue_heart:',
#  ':heart::heart::heart:',
#  ':heart::heart::heart::heart:',
#  ':heart::heart::heart::heart::heart::heart::heart::heart::heart::heart::heart::heart::heart::heart::heart:',
#  ':heart::heart::heart::heart::heart::heart::heart::heart::heart::heart::heart::syringe::syringe:',
#  ':heart::heart::heart::heart::sob:',
#  ':heart::heart::heart::heart_eyes:',
#  ':heart::heart::heart::kissing_heart::kissing_heart:',
#  ':heart::heart::heart::rose::pray:',
#  ':heart::joy::running:ud:male_sign:',
#  ':heart::kissing_heart:',
#  ':heart::ok_hand:🏻',
#  ':heart::palm_tree::palm_tree::heart:تصبحون',
#  ':heart::pray:🏻',
#  ':heart::punch:',
#  ':heart::ring:',
#  ':heart::rose::heart::rose:',
#  ':heart::sob:',
#  ':heart:ud:fire:',
#  ':heart:قلب',
#  ':heart_eyes:',
#  ':heart_eyes::blue_heart:',
#  ':heart_eyes::heart:',
#  ':heart_eyes::heart::heart:',
#  ':heart_eyes::heart_eyes:',
#  ':heart_eyes::heart_eyes::blue_heart::blue_heart:',
#  ':heart_eyes::hearts:',
#  ':heart_eyes::hearts:il',
#  ':heart_eyes::kissing_heart::thumbsup:🏻',
#  ':heart_eyes::pleading_face:',
#  ':heart_eyes::sob::blue_heart::blue_heart:',
#  ':heart_eyes::sob:اليوم',
#  ':heart_eyes::star_struck:',
#  ':heart_eyes:الحمدلله',
#  ':heart_eyes:❤',
#  ':heart_eyes_cat:ياعمري',
#  ':heartbeat:',
#  ':heartpulse:',
#  ':heartpulse:⚘',
#  ':hearts:',
#  ':hearts::ear_of_rice::rose::blossom::bouquet::bouquet::blossom::rose::ear_of_rice::hearts:',
#  ':hearts::hatching_chick:',
#  ':hearts::hearts:',
#  ':hearts::hearts::hearts:',
#  ':hearts::hearts::hearts::hearts::hearts:',
#  ':hearts::hearts::hearts::hearts::hearts::hearts::hearts::hearts::hearts:',
#  ':hearts::hearts::pray:',
#  ':hearts::hearts:بالتوفيق',
#  ':hearts::herb:',
#  ':hearts::joy:',
#  ':hearts::joy::joy:',
#  ':hearts::notes:',
#  ':hearts::pleading_face::rose:',
#  ':hearts::sob::sob:',
#  ':hearts::wink:',
#  ':hearts:علي',
#  ':hearts:للقلب',
#  ':hearts:هيا',
#  ':heavy_check_mark:',
#  ':heavy_check_mark::heavy_check_mark:*بعض',
#  ':heavy_dollar_sign:',
#  ':heavy_heart_exclamation:',
#  ':herb:',
#  ':herb::partly_sunny:️',
#  ':herb:fd',
#  ':hibiscus:',
#  ':hibiscus::blossom::rose::blossom::hibiscus:',
#  ':hibiscus::bouquet:',
#  ':hibiscus::broken_heart::hibiscus:',
#  ':hibiscus::cherry_blossom:',
#  ':hibiscus::green_heart::hibiscus:',
#  ':hibiscus::heart:',
#  ':hibiscus::heart::palms_up_together:🏼',
#  ':hibiscus::heart::united_arab_emirates:',
#  ':hibiscus::hearts:',
#  ':hibiscus::hibiscus:',
#  ':hibiscus::pray:',
#  ':hibiscus::purple_heart::butterfly:',
#  ':hibiscus::purple_heart::yellow_heart:اهوايه',
#  ':hibiscus::raised_hand:',
#  ':hibiscus::rose::hibiscus:',
#  ':hibiscus::smirk:',
#  ':hibiscus:fd',
#  ':hibiscus:الصديقات',
#  ':hibiscus:خااطره',
#  ':high_heel:',
#  ':high_heel::princess:🏻',
#  ':hiking_boot:',
#  ':hot_face:',
#  ':hourglass_flowing_sand:',
#  ':house:',
#  ':house_with_garden:',
#  ':hugs:',
#  ':hugs::blue_heart:fd:blue_heart:fd',
#  ':hugs::joy::joy:بس',
#  ':hugs::palms_up_together::palms_up_together::heart_eyes:الحمدلله',
#  ':hushed:',
#  ':imp:',
#  ':information_desk_person:🏻',
#  ':innocent:',
#  ':interrobang:',
#  ':interrobang::raised_hand:🏻',
#  ':japanese_goblin:بالله',
#  ':japanese_ogre::japanese_goblin:',
#  ':japanese_ogre::japanese_ogre:',
#  ':joy:',
#  ':joy::blue_heart:',
#  ':joy::broken_heart:',
#  ':joy::broken_heart::broken_heart:',
#  ':joy::broken_heart::facepalm:🏻ud:female_sign:',
#  ':joy::clap:',
#  ':joy::clap:🏻وك',
#  ':joy::clap:🏻وك:joy::clap:🏻لكن',
#  ':joy::clap:🏼',
#  ':joy::facepalm:',
#  ':joy::facepalm::broken_heart:',
#  ':joy::facepalm:ud:male_sign:',
#  ':joy::facepalm:🏻ud:male_sign:',
#  ':joy::facepalm:🏻\u200d:male_sign::broken_heart:',
#  ':joy::green_heart:',
#  ':joy::hand_over_mouth:',
#  ':joy::hand_over_mouth::running:🏼ud:female_sign::cartwheeling:🏻',
#  ':joy::heart:',
#  ':joy::heart_eyes::upside_down_face::pray:',
#  ':joy::hearts::hearts:',
#  ':joy::joy:',
#  ':joy::joy::blue_heart:',
#  ':joy::joy::broken_heart:',
#  ':joy::joy::broken_heart::broken_heart:',
#  ':joy::joy::clap:',
#  ':joy::joy::clap:تراني',
#  ':joy::joy::eyes:',
#  ':joy::joy::facepalm:🏻ud:female_sign:امزح',
#  ':joy::joy::facepalm:🏾ud:female_sign:',
#  ':joy::joy::grimacing::grimacing:',
#  ':joy::joy::grin::grin:',
#  ':joy::joy::grin:مارش',
#  ':joy::joy::gun::gun::sob::sob:',
#  ':joy::joy::heart::blue_heart:',
#  ':joy::joy::hearts::hearts:',
#  ':joy::joy::hibiscus::joy:',
#  ':joy::joy::kissing_heart:',
#  ':joy::joy::kuwait::kuwait::joy::joy:',
#  ':joy::joy::ok_hand:🏻',
#  ':joy::joy::ok_person:🏻ud:male_sign::sob::sob:',
#  ':joy::joy::pensive:',
#  ':joy::joy::punch:',
#  ':joy::joy::punch:🏻:punch:🏻:punch:🏻',
#  ':joy::joy::purple_heart:',
#  ':joy::joy::raised_hand:',
#  ':joy::joy::rofl:',
#  ':joy::joy::rofl::rofl:',
#  ':joy::joy::rofl::rofl::clap:🏻:clap:🏻',
#  ':joy::joy::running:ud:male_sign::running:ud:male_sign::man_dancing:',
#  ':joy::joy::running:🏻:running:🏻:walking:🏻:running:🏻:running:🏻',
#  ':joy::joy::running:🏻ud:female_sign:',
#  ':joy::joy::running:🏻ud:female_sign::running:🏻ud:female_sign:',
#  ':joy::joy::running:🏼ud:female_sign:',
#  ':joy::joy::running:🏽ud:female_sign::running:🏽ud:female_sign:',
#  ':joy::joy::slightly_smiling_face:',
#  ':joy::joy::smiley::smiley:',
#  ':joy::joy::sob:',
#  ':joy::joy::sob::sob:',
#  ':joy::joy::sob::sob::joy::joy:',
#  ':joy::joy::speak_no_evil:',
#  ':joy::joy::sweat_smile:',
#  ':joy::joy::thumbsdown:',
#  ':joy::joy::thumbsup:',
#  ':joy::joy::yellow_heart::yellow_heart::black_heart::black_heart:',
#  ':joy::joy:fdfd',
#  ':joy::joy:اتشمت',
#  ':joy::joy:ادري',
#  ':joy::joy:اطقطق',
#  ':joy::joy:اعرف',
#  ':joy::joy:الا',
#  ':joy::joy:الحشيمه',
#  ':joy::joy:الحمدلله',
#  ':joy::joy:الله',
#  ':joy::joy:الميناء',
#  ':joy::joy:امزح',
#  ':joy::joy:انا',
#  ':joy::joy:اى',
#  ':joy::joy:بترد',
#  ':joy::joy:بس',
#  ':joy::joy:جاب',
#  ':joy::joy:جابت',
#  ':joy::joy:حبيت',
#  ':joy::joy:حمدالله',
#  ':joy::joy:سوبهان',
#  ':joy::joy:شاهد',
#  ':joy::joy:شوفتي',
#  ':joy::joy:صدق',
#  ':joy::joy:ضحكتني',
#  ':joy::joy:عقول',
#  ':joy::joy:فظييعه',
#  ':joy::joy:كوميديا',
#  ':joy::joy:لا',
#  ':joy::joy:لابالله',
#  ':joy::joy:ما',
#  ':joy::joy:مايسويها',
#  ':joy::joy:مزاح',
#  ':joy::joy:نصابه',
#  ':joy::joy:واضح',
#  ':joy::joy:والله',
#  ':joy::joy:وكان',
#  ':joy::joy:ول',
#  ':joy::joy:يا',
#  ':joy::joy:ياخوفي',
#  ':joy::joy_cat::joy:',
#  ':joy::new_moon_with_face:',
#  ':joy::new_moon_with_face::running:🏻ud:female_sign:',
#  ':joy::ok_hand:',
#  ':joy::ok_hand:يوم',
#  ':joy::ok_person:🏻ud:female_sign:',
#  ':joy::palms_up_together:🏻',
#  ':joy::pleading_face:',
#  ':joy::pray:🏻…',
#  ':joy::punch:🏻',
#  ':joy::raised_hand:',
#  ':joy::raised_hands:',
#  ':joy::rofl:',
#  ':joy::rofl::joy:',
#  ':joy::rofl::joy::rofl:',
#  ':joy::rofl::joy::rofl::joy::rofl:',
#  ':joy::rofl:ياربيه',
#  ':joy::roll_eyes:',
#  ':joy::rose:',
#  ':joy::running:',
#  ':joy::running:ud:female_sign:',
#  ':joy::running:🏻ud:female_sign:',
#  ':joy::running:🏼\u200d:female_sign:',
#  ':joy::running:🏽ud:female_sign::running:🏽ud:female_sign::running:🏽ud:female_sign:',
#  ':joy::running_woman:',
#  ':joy::satisfied:',
#  ':joy::see_no_evil:',
#  ':joy::see_no_evil::running:🏻ud:female_sign:',
#  ':joy::smiley:هه',
#  ':joy::sob:',
#  ':joy::sob::sob:',
#  ':joy::sob::sob::joy:هه',
#  ':joy::sob::sob::running:🏻ud:female_sign:',
#  ':joy::sob::sob:بالله',
#  ':joy::sob:fd',
#  ':joy::sob:ووصيت',
#  ':joy::stuck_out_tongue_closed_eyes::stuck_out_tongue_closed_eyes:',
#  ':joy::stuck_out_tongue_winking_eye:',
#  ':joy::sweat_smile:',
#  ':joy::sweat_smile::sweat_smile:',
#  ':joy::thumbsup:🏻:thumbsup:🏻:thumbsup:🏻',
#  ':joy::unamused:',
#  ':joy::upside_down_face:',
#  ':joy::upside_down_face::heart_eyes::muscle::muscle::point_up::point_up:',
#  ':joy::v:',
#  ':joy::walking:ud:female_sign:',
#  ':joy::yellow_heart::yellow_heart:',
#  ':joy::zany_face:امزح',
#  ':joy:f:skull::broken_heart::broken_heart:',
#  ':joy:fc🏻',
#  ':joy:ff🏻شوفو',
#  ':joy:اطقطق',
#  ':joy:الحمد',
#  ':joy:الحمدلله',
#  ':joy:الزبده',
#  ':joy:النصر',
#  ':joy:حليلك',
#  ':joy:شوفوني',
#  ':joy:مايقدر',
#  ':joy:مو',
#  ':joy:هذولي',
#  ':joy:هذي',
#  ':joy:و',
#  ':joy:ي',
#  ':joy:❤',
#  ':joy:❤❤',
#  ':joy_cat:',
#  ':joy_cat::broken_heart:',
#  ':joy_cat::joy_cat:',
#  ':joy_cat::joy_cat::running_man:',
#  ':joy_cat::joy_cat:اخ',
#  ':joy_cat::joy_cat:الحمدلله',
#  ':joy_cat::joy_cat:جابت',
#  ':joy_cat::sob:',
#  ':joy_cat::sob::broken_heart:',
#  ':joy_cat::sparkling_heart::heart_eyes:',
#  ':joy_cat:fd',
#  ':joy_cat:طبعا',
#  ':kiss::heavy_heart_exclamation::heavy_heart_exclamation:',
#  ':kissing:',
#  ':kissing::kissing:',
#  ':kissing_closed_eyes:',
#  ':kissing_closed_eyes::kissing_closed_eyes:',
#  ':kissing_heart:',
#  ':kissing_heart::hearts::hearts:',
#  ':kissing_heart::kissing_heart:',
#  ':kissing_heart::rose:',
#  ':kissing_heart::wave:هروب',
#  ':kissing_smiling_eyes:',
#  ':knife:',
#  ':kuwait:',
#  ':leaves:',
#  ':leaves::bouquet:',
#  ':leaves::herb::sparkles::umbrella:️:heart_eyes::pray:🏻',
#  ':lebanon:',
#  ':lotus_position:🏻ud:female_sign:',
#  ':lotus_position:🏻ud:female_sign::broken_heart:',
#  ':loud_sound:',
#  ':loud_sound:من',
#  ':love_letter:',
#  ':lying_face:',
#  ':m::lion:',
#  ':man:🏼ud🦳',
#  ':man_shrugging:',
#  ':maple_leaf::maple_leaf::hibiscus:',
#  ':mask:',
#  ':mask::mask:',
#  ':mask::syringe::syringe:',
#  ':money_with_wings::medal_military:',
#  ':moneybag:',
#  ':monkey:',
#  ':monkey::monkey::joy::joy:',
#  ':monocle_face:',
#  ':morocco::crown::morocco:',
#  ':morocco::crown::morocco:متصدرين',
#  ':morocco::heart:',
#  ':mosque:',
#  ':mosque::timer_clock::green_heart::raised_hands:',
#  ':moyai:',
#  ':moyai::broken_heart::broken_heart:',
#  ':moyai::moyai:',
#  ':moyai::moyai::broken_heart:',
#  ':moyai::smoking:',
#  ':moyai::umbrella:️',
#  ':muscle:',
#  ':muscle:🏻:star_struck::orange_heart::orange_heart:',
#  ':musical_note:',
#  ':musical_score:',
#  ':musical_score::two_hearts:',
#  ':nail_care:',
#  ':nail_care::hand_over_mouth:',
#  ':nail_care::nail_care:',
#  ':nail_care:🏻',
#  ':nail_care:🏻ليتهم',
#  ':nail_care:🏼',
#  ':nauseated_face:',
#  ':nauseated_face::nauseated_face:',
#  ':negative_squared_cross_mark:',
#  ':negative_squared_cross_mark::negative_squared_cross_mark:',
#  ':nerd_face:',
#  ':nerd_face::wink::nerd_face:',
#  ':neutral_face:',
#  ':neutral_face::neutral_face:',
#  ':neutral_face:خلصتي',
#  ':neutral_face:و',
#  ':neutral_face:ياللهول',
#  ':new_moon_with_face:',
#  ':new_moon_with_face::blue_heart:',
#  ':new_moon_with_face::broken_heart:',
#  ':new_moon_with_face::broken_heart::broken_heart:',
#  ':new_moon_with_face::full_moon_with_face:سوبهان',
#  ':new_moon_with_face::hand_over_mouth:',
#  ':new_moon_with_face::joy:',
#  ':new_moon_with_face::joy::joy:',
#  ':new_moon_with_face::joy::joy::broken_heart:',
#  ':new_moon_with_face::new_moon_with_face:',
#  ':new_moon_with_face::new_moon_with_face::joy::joy:',
#  ':new_moon_with_face::raised_back_of_hand:🏻',
#  ':new_moon_with_face::roll_eyes::roll_eyes:',
#  ':new_moon_with_face::running:🏻ud:female_sign:',
#  ':new_moon_with_face::satisfied:',
#  ':no_entry:️',
#  ':no_entry:️اهربوا',
#  ':no_entry_sign::punch:🏻',
#  ':no_good:',
#  ':no_good:ud:female_sign:',
#  ':no_mouth:',
#  ':no_mouth::no_mouth:',
#  ':nose:الوحده',
#  ':notes:❤',
#  ':ok_hand:',
#  ':ok_hand::pray::heartbeat::heartbeat:',
#  ':ok_hand::rose:',
#  ':ok_hand::shrug:ud:female_sign::shrug:ud:female_sign:',
#  ':ok_hand:والنوم',
#  ':ok_hand:🏻',
#  ':ok_hand:🏻:ok_hand:🏻',
#  ':ok_hand:🏻:ok_hand:🏻:ok_hand:🏻:ok_hand:🏻:ok_hand:🏻',
#  ':ok_hand:🏻:upside_down_face:',
#  ':ok_hand:🏻:yellow_heart::joy::joy:',
#  ':ok_hand:🏻ولكن',
#  ':ok_hand:🏼',
#  ':ok_hand:🏼:roll_eyes:',
#  ':ok_hand:🏽اركدو',
#  ':ok_person:ud:male_sign:',
#  ':ok_person:🏻ud:female_sign:',
#  ':ok_person:🏻ud:female_sign::bangbang:',
#  ':ok_person:🏻ud:male_sign:',
#  ':ok_person:🏻\u200d:male_sign:',
#  ':open_mouth:ud:dash:',
#  ':orange_heart:',
#  ':orange_heart::black_heart::orange_heart::black_heart::orange_heart::black_heart:',
#  ':orange_heart::black_heart:fd',
#  ':orange_heart::crossed_fingers:🏽',
#  ':otter::black_heart::saudi_arabia:',
#  ':owl:',
#  ':palm_tree::saudi_arabia::palm_tree:عاشت',
#  ':palms_up_together:',
#  ':palms_up_together::blue_heart::yellow_heart:',
#  ':palms_up_together::cry::broken_heart:',
#  ':palms_up_together::heart:',
#  ':palms_up_together::heart::green_heart:',
#  ':palms_up_together::heart::green_heart::smiling_face_with_three_hearts:',
#  ':palms_up_together::heart:يوم',
#  ':palms_up_together::hibiscus:',
#  ':palms_up_together::leaves::tulip::leaves:',
#  ':palms_up_together::morocco::crown::morocco:',
#  ':palms_up_together::palms_up_together:',
#  ':palms_up_together::palms_up_together::blossom::blossom:',
#  ':palms_up_together::palms_up_together::disappointed_relieved:',
#  ':palms_up_together::palms_up_together::pray::pray:',
#  ':palms_up_together::palms_up_together::tulip:',
#  ':palms_up_together::palms_up_together:دائما',
#  ':palms_up_together::palms_up_together:🕊:shamrock:',
#  ':palms_up_together::pray:',
#  ':palms_up_together::pray:الحمدلله',
#  ':palms_up_together::rose:',
#  ':palms_up_together::saudi_arabia:',
#  ':palms_up_together::saudi_arabia::heart::saudi_arabia:',
#  ':palms_up_together::yellow_heart:',
#  ':palms_up_together:الحمد',
#  ':palms_up_together:لك',
#  ':palms_up_together:والقادم',
#  ':palms_up_together:وكملوها',
#  ':palms_up_together:🏻',
#  ':palms_up_together:🏻:blue_heart:',
#  ':palms_up_together:🏻:heart:',
#  ':palms_up_together:🏻:palms_up_together:🏻:palms_up_together:🏻:palms_up_together:🏻',
#  ':palms_up_together:🏻:rose::heart_eyes:',
#  ':palms_up_together:🏻:saudi_arabia::saudi_arabia::saudi_arabia:',
#  ':palms_up_together:🏻fd',
#  ':palms_up_together:🏼',
#  ':palms_up_together:🏼:heart:',
#  ':palms_up_together:🏼:palms_up_together:🏼:palms_up_together:🏼:palms_up_together:🏼',
#  ':palms_up_together:🏼:palms_up_together:🏼:palms_up_together:🏼:palms_up_together:🏼:palms_up_together:🏼:palms_up_together:🏼:palms_up_together:🏼',
#  ':palms_up_together:🏼:saudi_arabia::kaaba:',
#  ':parrot:',
#  ':parrot:انا',
#  ':partly_sunny:️:herb:',
#  ':partying_face:',
#  ':partying_face::cartwheeling:🏾',
#  ':partying_face::clap::dancer:',
#  ':partying_face::partying_face:',
#  ':partying_face::pray:',
#  ':pensive:',
#  ':pensive::broken_heart:',
#  ':pensive::broken_heart::broken_heart:',
#  ':pensive::broken_heart::pensive:',
#  ':pensive::facepalm:🏼ud:male_sign:',
#  ':pensive::hearts::hearts::hearts:',
#  ':pensive::joy:',
#  ':pensive::joy::handshake:',
#  ':pensive::joy::joy:',
#  ':pensive::palms_up_together:🏻',
#  ':pensive::pensive:',
#  ':pensive::weary:',
#  ':pensive:fd',
#  ':persevere:',
#  ':persevere::persevere:',
#  ':persevere::persevere::sob::sob:',
#  ':person_with_veil:',
#  ':pinching_hand:🏻',
#  ':place_of_worship::dog:عمريسنابيrhrh',
#  ':pleading_face:',
#  ':pleading_face::broken_heart:',
#  ':pleading_face::broken_heart::nerd_face::rofl::rofl:',
#  ':pleading_face::green_heart::green_heart:',
#  ':pleading_face::heart:',
#  ':pleading_face::heartpulse::heartpulse::sparkles:',
#  ':pleading_face::heartpulse::heartpulse:كلميهم',
#  ':pleading_face::hearts:',
#  ':pleading_face::persevere:',
#  ':pleading_face::pleading_face:',
#  ':pleading_face::purple_heart:',
#  ':pleading_face:fd',
#  ':pleading_face:fdfdما',
#  ':pleading_face:سامحيني',
#  ':point_down:',
#  ':point_down::point_down:',
#  ':point_down:حول',
#  ':point_down:🏻',
#  ':point_down:🏻:joy::joy::running:🏻ud:female_sign:',
#  ':point_down:🏼',
#  ':point_down:🏽:point_down:🏽:point_down:🏽:point_down:🏽:point_down:🏽:point_down:🏽',
#  ':point_down:🏾',
#  ':point_left:🏻',
#  ':point_left:🏻:point_right:🏻',
#  ':point_right:',
#  ':point_up:',
#  ':point_up_2:🏻',
#  ':point_up_2:🏻:sob:',
#  ':point_up_2:🏽',
#  ':postal_horn:',
#  ':pout:',
#  ':pout::pout:',
#  ':pouting_cat:',
#  ':pray:',
#  ':pray::blossom::pray:',
#  ':pray::blue_heart::blue_heart::saudi_arabia::thumbsup::joy::upside_down_face::heart_eyes:',
#  ':pray::green_heart:',
#  ':pray::green_heart::herb::green_heart::pray:',
#  ':pray::hearts:',
#  ':pray::herb::pray:',
#  ':pray::herb::pray::egypt::pray::herb::pray:',
#  ':pray::joy:',
#  ':pray::ok_hand:',
#  ':pray::palms_up_together:',
#  ':pray::pray:',
#  ':pray::pray::blue_heart::blue_heart:',
#  ':pray::pray::palms_up_together::palms_up_together:',
#  ':pray::pray::united_arab_emirates::united_arab_emirates::united_arab_emirates:',
#  ':pray::rose:',
#  ':pray::saudi_arabia::green_heart:',
#  ':pray::saudi_arabia::green_heart::blue_heart::saudi_arabia::heart:',
#  ':pray:fd',
#  ':pray:fdfd',
#  ':pray:الحمدلله',
#  ':pray:والشكر',
#  ':pray:🏻',
#  ':pray:🏻:blue_heart::blue_heart:',
#  ':pray:🏻:heart:',
#  ':pray:🏻:pleading_face:',
#  ':pray:🏻:sparkles:',
#  ':pray:🏻fd',
#  ':pray:🏼',
#  ':pray:🏼:blue_heart::blue_heart:',
#  ':pray:🏼:heart:',
#  ':pray:🏼:heartpulse:',
#  ':pray:🏼:joy:',
#  ':pray:🏼❤:pleading_face:',
#  ':pray:🏽',
#  ':punch::punch:',
#  ':punch:🏻',
#  ':punch:🏼',
#  ':purple_heart:',
#  ':purple_heart::bouquet::orange_heart::heart_eyes:',
#  ':purple_heart::hibiscus:',
#  ':purple_heart::purple_heart:',
#  ':purple_heart:°➥',
#  ':purple_heart:قل',
#  ':purple_heart:❣',
#  ':qatar:',
#  ':rabbit::rose:',
#  ':raised_back_of_hand:🏻',
#  ':raised_back_of_hand:🏼',
#  ':raised_back_of_hand:🏽',
#  ':raised_eyebrow:',
#  ':raised_eyebrow::joy::joy:',
#  ':raised_eyebrow::raised_eyebrow:',
#  ':raised_eyebrow::thumbsdown:',
#  ':raised_hand:',
#  ':raised_hand:🏻',
#  ':raised_hand:🏻كفك',
#  ':raised_hand:🏽:raised_hand:🏽:ok_hand:🏽:ok_hand:🏽',
#  ':raised_hands:',
#  ':raised_hands::raised_hands:',
#  ':raised_hands:🏻',
#  ':raising_hand_woman:',
#  ':ram:',
#  ':red_car:',
#  ':red_circle:',
#  ':red_circle::red_circle:',
#  ':red_circle:خل',
#  ':relaxed:',
#  ':relaxed::sunglasses:',
#  ':relaxed:واتكلي',
#  ':relieved:',
#  ':relieved::heart_eyes::heart:',
#  ':relieved::joy:',
#  ':relieved::purple_heart::purple_heart:',
#  ':relieved::raised_hand:',
#  ':relieved::raised_hand:🏻',
#  ':relieved::wink:',
#  ':revolving_hearts:',
#  ':revolving_hearts::palms_up_together:🏻',
#  ':revolving_hearts::pray:',
#  ':ribbon:',
#  ':rofl:',
#  ':rofl::broken_heart:',
#  ':rofl::joy:',
#  ':rofl::joy::joy:',
#  ':rofl::joy::joy::running:🏿ud:female_sign::running:🏿ud:female_sign:',
#  ':rofl::joy::running:🏻ud:female_sign:',
#  ':rofl::joy::sob::sob:',
#  ':rofl::joy_cat::ok_hand::running_man:',
#  ':rofl::lying_face:',
#  ':rofl::ok_hand:',
#  ':rofl::ok_hand:🏻',
#  ':rofl::pinched_fingers:🏻',
#  ':rofl::rofl:',
#  ':rofl::rofl::blue_heart::zany_face::zany_face:الان',
#  ':rofl::rofl::hand_over_mouth:',
#  ':rofl::rofl::joy::joy:',
#  ':rofl::rofl::partying_face::rofl::rofl:',
#  ':rofl::rofl::rose::hibiscus::hibiscus:والله',
#  ':rofl::rofl::thumbsup::bouquet::bouquet:',
#  ':rofl::rofl::weary:',
#  ':rofl::rofl:ادري',
#  ':rofl::rofl:استغفر',
#  ':rofl::rofl:المشكله',
#  ':rofl::rofl:دحين',
#  ':rofl::rofl:مصخره',
#  ':rofl::rofl:وااي',
#  ':rofl::rofl:ودفت',
#  ':rofl::running:🏻ud:female_sign:',
#  ':rofl::sob::sob:',
#  ':rofl::stuck_out_tongue:',
#  ':rofl::zany_face:',
#  ':rofl:اذا',
#  ':rofl:المفروض',
#  ':rofl:او',
#  ':roll_eyes:',
#  ':roll_eyes::hand_over_mouth:مسكين',
#  ...]

# %%
stoi = { ch:i for i,ch in enumerate(vocab) }
itos = { i:ch for i,ch in enumerate(vocab) }

# Encoder: takes a string, outputs a list of integers
encode = lambda s: [stoi[c] for c in s.split() if c in stoi]
# Decoder: takes a list of integers, outputs a string
decode = lambda l: ' '.join([itos[i] for i in l])

print(f'Vocab size: {len(vocab)}')
# Example
test_sentence = data[0]
encoded = encode(test_sentence)
print(f'Example encoded: {encoded[:10]}...')
print(f'Example decoded: {decode(encoded[:10])}...')
# Out:
# Vocab size: 55271
# Example encoded: [41670, 40164, 30086, 7490, 21224, 9469, 7307, 33805, 17242, 9882]...
# Example decoded: نعم من علامات الجمال تلك الطيبه التي لاترى بل العين...

# %%
# Combine all data into a single string to encode the whole dataset
all_text = ' '.join(data)
# Encode the text and convert to a torch tensor
dataset_ids = encode(all_text)
dataset = torch.tensor(dataset_ids, dtype=torch.long)

print(f'Dataset tensor shape: {dataset.shape}')
print(f'First 20 tokens: {dataset[:20]}')
# Out:
# Dataset tensor shape: torch.Size([284871])
# First 20 tokens: tensor([41670, 40164, 30086,  7490, 21224,  9469,  7307, 33805, 17242,  9882,
#         49286, 21226, 10399, 42559, 42819,  7490,  8313, 34245,  2206, 38766])

# %%
MASTER_CONFIG = {
    "vocab_size": len(vocab)
}

# %%
def get_batches(data, split, batch_size, context_window, config = MASTER_CONFIG):
  # Ensure we are using the tensor data
  train = data[:int(.8 * len(data))]
  val = data[int(.8* len(data)): int(.9 * len(data))]
  test = data[int(.9* len(data)):]

  batch_data = train
  if split == 'val':
    batch_data = val
  if split == 'test':
    batch_data = test

  # pick random starting points
  # .size(0) or len() works on tensors
  ix = torch.randint(0, batch_data.size(0) - context_window - 1, (batch_size,))
  x = torch.stack([batch_data[i:i+context_window] for i in ix]).long()
  y = torch.stack([batch_data[i+1:i+1+context_window] for i in ix]).long()
  return x, y

MASTER_CONFIG.update({
    'batch_size': 8,
    'context_window': 16
})

# Use 'dataset' (the tensor) instead of 'data' (the list)
xs, ys = get_batches(dataset, 'train', MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'])

# Decode and show samples
print([(decode(xs[i].tolist()), decode(ys[i].tolist())) for i in range(len(xs))])
# Out:
# [('الشرهه مو عليه عالي يحط اي فيديو يلقاه بالشارع من الى الحمدلله المال وفير الحمد والشكر', 'مو عليه عالي يحط اي فيديو يلقاه بالشارع من الى الحمدلله المال وفير الحمد والشكر لله'), ('اطقطق معاكن:joy_cat: انا ماعندي مشكله سواء كنت شيعي او سني بس لا تجي تهين عقائدي و', 'معاكن:joy_cat: انا ماعندي مشكله سواء كنت شيعي او سني بس لا تجي تهين عقائدي و تسب'), ('لله ثم لابطالنا الف مليون مبروك للزعيم وعشاقه اليوم المدرج الفخم عشره على عشره القوه الزرقاء', 'ثم لابطالنا الف مليون مبروك للزعيم وعشاقه اليوم المدرج الفخم عشره على عشره القوه الزرقاء الف'), ('صباح فاينل وتعبانه وحرارتي وماقدرت اذاكر ولا قدرت انام الليل من التعب ويوم جيت البس الصباح', 'فاينل وتعبانه وحرارتي وماقدرت اذاكر ولا قدرت انام الليل من التعب ويوم جيت البس الصباح اكتشفت'), ('مستفزه حتى كنت اطقطق واقول ابهامي :sob::thumbsdown:🏽 لي ساعه اطقطق ولا عرفتي الفكره للحين هه :sob::sob:', 'حتى كنت اطقطق واقول ابهامي :sob::thumbsdown:🏽 لي ساعه اطقطق ولا عرفتي الفكره للحين هه :sob::sob: بس'), ('فينا وفيهم العيد صحيح بس اهم الشيء النتيجه النهائيه جاب ام ام العيد :joy::joy: طبيعي ايلاي', 'وفيهم العيد صحيح بس اهم الشيء النتيجه النهائيه جاب ام ام العيد :joy::joy: طبيعي ايلاي قبله'), ('والشكر النصر الاتحاد ناس تركض وراء رتويت ومتابعات في تويتر وناس تركض وراء البطولات الحمدلله والشكر', 'النصر الاتحاد ناس تركض وراء رتويت ومتابعات في تويتر وناس تركض وراء البطولات الحمدلله والشكر على'), ('الله والقروب:sob::sob: الحمد لله حمدا لا حدود له والشكر لله اسرارا واعلانا صباح الخير الحمدلله والشكر', 'والقروب:sob::sob: الحمد لله حمدا لا حدود له والشكر لله اسرارا واعلانا صباح الخير الحمدلله والشكر على')]

# %%
@torch.no_grad()  # don't compute gradients for this function
def evaluate_loss(model, config=MASTER_CONFIG):
    out = {}
    model.eval()
    for split in ["train", "val"]:
        losses = []
        for _ in range(10):
            xb, yb = get_batches(dataset, split, config['batch_size'], config['context_window'])
            _, loss = model(xb, yb)
            losses.append(loss.item())
        out[split] = np.mean(losses)
    model.train()
    return out

# %%
class SimpleBrokenModel(nn.Module):
    def __init__(self, config=MASTER_CONFIG):
        super().__init__()
        self.config = config

        self.embedding = nn.Embedding(config['vocab_size'], config['d_model'])
        self.linear = nn.Sequential(
            nn.Linear(config['d_model'], config['d_model']),
            nn.ReLU(),
            nn.Linear(config['d_model'], config['vocab_size']),
        )

        print("model params:", sum([m.numel() for m in self.parameters()]))

    def forward(self, idx, targets=None):
        x = self.embedding(idx)
        a = self.linear(x)
        logits = F.softmax(a, dim=-1)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, self.config['vocab_size']), targets.view(-1))
            return logits, loss

        else:
            return logits

MASTER_CONFIG.update({
    'd_model': 128,
})
model = SimpleBrokenModel(MASTER_CONFIG)
xs, ys = get_batches(dataset, 'train', MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'])

logits, loss = model(xs, ys)
# Out:
# model params: 14221159

# %%
MASTER_CONFIG.update({
    'epochs': 1000,
    'log_interval': 10,
    'batch_size': 32,
})
model = SimpleBrokenModel(MASTER_CONFIG)

optimizer = torch.optim.Adam(
    model.parameters(),
)

def train(model, optimizer, scheduler=None, config=MASTER_CONFIG, print_logs=False):
    losses = []
    start_time = time.time()
    for epoch in range(config['epochs']):
        optimizer.zero_grad()

        xs, ys = get_batches(dataset, 'train', config['batch_size'], config['context_window'])
        logits, loss = model(xs, targets=ys)
        loss.backward()
        optimizer.step()

        if scheduler:
            scheduler.step()

        if epoch % config['log_interval'] == 0:
            batch_time = time.time() - start_time
            x = evaluate_loss(model)
            losses += [x]
            if print_logs:
                print(f"Epoch {epoch} | val loss {x['val']:.3f} | Time {batch_time:.3f} | ETA in seconds {batch_time * (config['epochs'] - epoch)/config['log_interval'] :.3f}")
            start_time = time.time()

            if scheduler:
                print("lr: ", scheduler.get_lr())

    print("validation loss: ", losses[-1]['val'])
    return pd.DataFrame(losses).plot()

train(model, optimizer)
# Out:
# model params: 14221159
# validation loss:  10.822119426727294
# <Axes: >

# %%
class SimpleModel(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config

        self.embedding = nn.Embedding(config['vocab_size'], config['d_model'])
        self.linear = nn.Sequential(
            nn.Linear(config['d_model'], config['d_model']),
            nn.ReLU(),
            nn.Linear(config['d_model'], config['vocab_size']),
        )

        print("model params:", sum([m.numel() for m in self.parameters()]))

    def forward(self, idx, targets=None):
        x = self.embedding(idx)
        logits = self.linear(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, self.config['vocab_size']), targets.view(-1))
            return logits, loss

        else:
            return logits

model = SimpleModel(MASTER_CONFIG)
xs, ys = get_batches(dataset, 'train', MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'])

logits, loss = model(xs, ys)
optimizer = torch.optim.Adam(model.parameters())
train(model, optimizer)
# Out:
# model params: 14221159

# %%
def generate(model, config=MASTER_CONFIG, max_new_tokens=30):
    idx = torch.zeros(5, 1).long()
    for _ in range(max_new_tokens):
        # call the model
        logits = model(idx[:, -config['context_window']:])
        last_time_step_logits = logits[
            :, -1, :
        ]  # all the batches (1), last time step, all the logits
        p = F.softmax(last_time_step_logits, dim=-1)  # softmax to get probabilities
        idx_next = torch.multinomial(
            p, num_samples=1
        )  # sample from the distribution to get the next token
        idx = torch.cat([idx, idx_next], dim=-1)  # append to the sequence
    return [decode(x) for x in idx.tolist()]

generate(model)

# %%
class RMSNorm(nn.Module):
    def __init__(self, layer_shape, eps=1e-8, bias=False):
        super(RMSNorm, self).__init__()
        self.register_parameter("scale", nn.Parameter(torch.ones(layer_shape)))

    def forward(self, x):
        """
        assumes shape is (batch, seq_len, d_model)
        """
        # frob norm is not the same as RMS. RMS = 1/sqrt(N) * frob norm
        ff_rms = torch.linalg.norm(x, dim=(1,2)) * x[0].numel() ** -.5
        raw = x / ff_rms.unsqueeze(-1).unsqueeze(-1)
        return self.scale[:x.shape[1], :].unsqueeze(0) * raw

config = {
    'batch_size': 5,
    'context_window': 11,
    'd_model': 13,
}
batch = torch.randn((config['batch_size'], config['context_window'], config['d_model']))
m = RMSNorm((config['context_window'], config['d_model']))
g = m(batch)
print(g.shape)

# %%
rms = torch.linalg.norm(batch, dim=(1,2)) * (batch[0].numel() ** -.5)

# scaled_batch.var(dim=(1,2))
assert torch.linalg.norm( torch.arange(5).float() ) == (torch.arange(5).float() ** 2 ).sum() ** .5
rms = torch.linalg.norm( torch.arange(5).float() ) * (torch.arange(5).numel() ** -.5)
assert torch.allclose(torch.linalg.norm(torch.arange(5).float() / rms), torch.tensor(5 ** .5))
ff_rms = torch.linalg.norm(batch, dim=(1,2)) * batch.shape[1:].numel() ** -.5

# RMS for sure
ffx = torch.zeros_like(batch)
for i in range(batch.shape[0]):
    ffx[i] = batch[i] / ff_rms[i]
assert torch.allclose(torch.linalg.norm(ffx, dim=(1,2)) ** 2, torch.tensor(143).float())
assert torch.allclose(ffx, g)

# %%
class SimpleModel_RMS(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config

        self.embedding = nn.Embedding(config['vocab_size'], config['d_model'])
        self.rms = RMSNorm((config['context_window'], config['d_model']))
        self.linear = nn.Sequential(
            nn.Linear(config['d_model'], config['d_model']),
            nn.ReLU(),
            nn.Linear(config['d_model'], config['vocab_size']),
        )

        print("model params:", sum([m.numel() for m in self.parameters()]))

    def forward(self, idx, targets=None):
        x = self.embedding(idx)
        x = self.rms(x) # rms pre-normalization
        logits = self.linear(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, self.config['vocab_size']), targets.view(-1))
            return logits, loss

        else:
            return logits

model = SimpleModel_RMS(MASTER_CONFIG)
xs, ys = get_batches(dataset, 'train', MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'])

logits, loss = model(xs, ys)
optimizer = torch.optim.Adam(model.parameters())
train(model, optimizer)

# %%
def get_rotary_matrix(context_window, embedding_dim):
    R = torch.zeros((context_window, embedding_dim, embedding_dim), requires_grad=False)
    for position in range(context_window):
        for i in range(embedding_dim//2):
            theta = 10000. ** (-2.*(i - 1) / embedding_dim)
            m_theta = position * theta
            R[position, 2*i,2*i] = np.cos(m_theta)
            R[position, 2*i,2*i+1] = - np.sin(m_theta)
            R[position, 2*i+1,2*i] = np.sin(m_theta)
            R[position, 2*i+1,2*i+1] = np.cos(m_theta)
    return R

# %%
K = 3
config = {
    'batch_size': 10,
    'd_model': 32,
    'n_heads': 8,
    'context_window': K**2,
}
batch = torch.randn(1, config['context_window'], config['d_model'])
R = get_rotary_matrix(config['context_window'], config['d_model'])
fig, ax = plt.subplots(K, K, figsize=(K * 3, K * 4))

for i in range(K):
    for j in range(K):
        ax[i, j].imshow(R[i * K + j, :, :].detach().numpy())
        ax[i, j].set_title(f'rotation at {i * K + j}')

# %%
config = {
    'd_model': 128,
    'context_window': 16,
}

R = get_rotary_matrix(config['context_window'], config['d_model'])
x = torch.randn(config['d_model'])
y = torch.randn(config['d_model'])

m = 3
n = 13

x_m = R[m,:,:] @ x
x_n = R[n,:,:] @ y

assert torch.isclose(x_m @ x_n, x @ R[n-m,:,:] @ y)

# %%
config = {
    'batch_size': 10,
    'd_model': 512,
    'n_heads': 8,
    'context_window': 16,
}

class RoPEAttentionHead(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        self.w_q = nn.Linear(config['d_model'], config['d_model'], bias=False)
        self.w_k = nn.Linear(config['d_model'], config['d_model'], bias=False)
        self.w_v = nn.Linear(config['d_model'], config['d_model'], bias=False)

        self.R = get_rotary_matrix(config['context_window'], config['d_model'])

    def get_rotary_matrix(context_window, embedding_dim):
        R = torch.zeros((context_window, embedding_dim, embedding_dim), requires_grad=False)
        for position in range(context_window):
            for i in range(embedding_dim//2):
                theta = 10000. ** (-2.*(i - 1) / embedding_dim)
                m_theta = position * theta
                R[position, 2*i,2*i] = np.cos(m_theta)
                R[position, 2*i,2*i+1] = - np.sin(m_theta)
                R[position, 2*i+1,2*i] = np.sin(m_theta)
                R[position, 2*i+1,2*i+1] = np.cos(m_theta)
        return R

    def forward(self, x, return_attn_weights=False):
      b,m,d = x.shape

      q = self.w_q(x)
      k = self.w_k(x)
      v = self.w_v(x)
      q_rotated = (torch.bmm(q.transpose(0,1), self.R[:m])).transpose(0,1)
      k_rotated = (torch.bmm(k.transpose(0,1), self.R[:m])).transpose(0,1)
      activations = F.scaled_dot_product_attention(
          q_rotated,k_rotated,v,dropout_p =.1)

      if return_attn_weights:
          attn_weights = torch.bmm(q_rotated, k_rotated.transpose(1,2)) / np.sqrt(d)
          attn_weights = F.softmax(attn_weights, dim=-1)
          return activations, attn_weights
      return activations

layer = RoPEAttentionHead(config)
batch = torch.randn((config['batch_size'], config['context_window'], config['d_model']))
output, attn_weights = layer(batch, return_attn_weights=True)

# %%
x = torch.randn((config['batch_size'], config['context_window'], config['d_model']))

q = layer.w_q(x)
k = layer.w_k(x)
v = layer.w_v(x)

q_rotated = torch.zeros_like(x)
k_rotated = torch.zeros_like(x)
v_rotated = torch.zeros_like(x)

for position in range(config['context_window']):
    q_rotated[:,position,:] = torch.matmul(q[:,position,:], layer.R[position,:,:])
    k_rotated[:,position,:] = torch.matmul(k[:,position,:], layer.R[position,:,:])
    v_rotated[:,position,:] = torch.matmul(v[:,position,:], layer.R[position,:,:])

q_rotated = (torch.bmm(q.transpose(0,1), layer.R)).transpose(0,1)
k_rotated = (torch.bmm(k.transpose(0,1), layer.R)).transpose(0,1)
v_out = (torch.bmm(v.transpose(0,1), layer.R)).transpose(0,1)

assert torch.allclose(q.transpose(0,1)[0], q[:,0,:])
assert torch.allclose(q.transpose(0,1)[0] @ layer.R[0], q[:,0,:] @ layer.R[0])
assert torch.allclose(q_rotated, q_rotated)

# %%
config = {
    'batch_size': 1,
    'd_model': 2,
    'n_heads': 2,
    'context_window': 3,
}

layer = RoPEAttentionHead(config)
batch = torch.ones((config['batch_size'], config['context_window'], config['d_model']))
output, attn_weights = layer(batch, return_attn_weights=True)

m = 0
x_q = batch[0, m]
q = layer.R[m,:,:] @ layer.w_q(x_q)

assert torch.allclose(layer.w_q(x_q), layer.w_q.weight @ x_q)
assert torch.allclose(q, layer.R[m, :, :] @ layer.w_q.weight @ x_q)

n = 2
x_k = batch[0, n]
k = layer.R[n,:,:] @ layer.w_k(x_k)

assert torch.allclose(layer.w_k(x_k), layer.w_k.weight @ x_k)
assert torch.allclose(k, layer.R[n, :, :] @ layer.w_k.weight @ x_k)

assert q.T @ k == q @ k # transpose is redundant
assert torch.allclose(q @ k, x_k.T @ layer.w_k.weight.T @ layer.R[n, :, :].T @ layer.R[m, :, :] @ layer.w_q.weight @ x_q)
assert torch.allclose(q @ k, x_k.T @ layer.w_k.weight.T @ layer.R[n-m, :, :].T @ layer.w_q.weight @ x_q)

# %%
# definitely there's an optimization we could make where we cache the rotation matrices, but skip.
class RoPEMultiheadAttention(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        self.heads = nn.ModuleList([
            RoPEAttentionHead(config) for _ in range(config['n_heads'])
        ])
        self.linear = nn.Linear(config['n_heads'] * config['d_model'], config['d_model'])
        self.dropout = nn.Dropout(.1)

    def forward(self, x):
        heads = [h(x) for h in self.heads]
        x = torch.cat(heads, dim=-1)
        x = self.linear(x)
        x = self.dropout(x)
        return x

MASTER_CONFIG.update({
    'n_heads': 8,
})
layer = RoPEMultiheadAttention(MASTER_CONFIG)
batch = torch.ones((MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'], MASTER_CONFIG['d_model']))
output = layer(batch)
output.shape

# %%
class RopeModel(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config

        self.embedding = nn.Embedding(config['vocab_size'], config['d_model'])
        self.rms = RMSNorm((config['context_window'], config['d_model']))
        self.rope_attention = RoPEMultiheadAttention(config)

        self.linear = nn.Sequential(
            nn.Linear(config['d_model'], config['d_model']),
            nn.ReLU(),
        )

        self.last_linear = nn.Linear(config['d_model'], config['vocab_size'])

        print("model params:", sum([m.numel() for m in self.parameters()]))

    def forward(self, idx, targets=None):
        x = self.embedding(idx)

        # one block of attention
        x = self.rms(x) # rms pre-normalization
        x = x + self.rope_attention(x)

        x = self.rms(x) # rms pre-normalization
        x = x + self.linear(x)

        logits = self.last_linear(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, self.config['vocab_size']), targets.view(-1))
            return logits, loss

        else:
            return logits

model = RopeModel(MASTER_CONFIG)
xs, ys = get_batches(dataset, 'train', MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'])

logits, loss = model(xs, ys)
optimizer = torch.optim.Adam(model.parameters())
train(model, optimizer)

# %%
generate(model, config=MASTER_CONFIG)

# %%
MASTER_CONFIG.update({
    'n_heads': 8,
})
layer = RoPEAttentionHead(MASTER_CONFIG)
batch = torch.ones((MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'], MASTER_CONFIG['d_model']))
output, attn_weights = layer(batch, return_attn_weights=True)

plt.imshow(attn_weights[0].detach().numpy(), interpolation='nearest')
plt.colorbar()

# %%
config = {
    'batch_size': 10,
    'd_model': 512,
    'n_heads': 8,
    'context_window': 16,
}

class RoPEMaskedAttentionHead(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        self.w_q = nn.Linear(config['d_model'], config['d_model'], bias=False)
        self.w_k = nn.Linear(config['d_model'], config['d_model'], bias=False)
        self.w_v = nn.Linear(config['d_model'], config['d_model'], bias=False)

        self.R = get_rotary_matrix(config['context_window'], config['d_model'])

    def get_rotary_matrix(context_window, embedding_dim):
        R = torch.zeros((context_window, embedding_dim, embedding_dim), requires_grad=False)
        for position in range(context_window):
            for i in range(embedding_dim//2):
                theta = 10000. ** (-2.*(i - 1) / embedding_dim)
                m_theta = position * theta
                R[position, 2*i,2*i] = np.cos(m_theta)
                R[position, 2*i,2*i+1] = - np.sin(m_theta)
                R[position, 2*i+1,2*i] = np.sin(m_theta)
                R[position, 2*i+1,2*i+1] = np.cos(m_theta)
        return R

    def forward(self, x, return_attn_weights=False):
        b,m,d = x.shape

        q = self.w_q(x)
        k = self.w_k(x)
        v = self.w_v(x)

        q_rotated = (torch.bmm(q.transpose(0,1), self.R[:m])).transpose(0,1)
        k_rotated = (torch.bmm(k.transpose(0,1), self.R[:m])).transpose(0,1)

        activations = F.scaled_dot_product_attention(
            q_rotated,k_rotated,v,dropout_p =.1, is_causal=True
        )

        if return_attn_weights:
            attn_mask = torch.tril(torch.ones((m,m)), diagonal=0)
            attn_weights = torch.bmm(q_rotated, k_rotated.transpose(1,2)) / np.sqrt(d) + attn_mask
            attn_weights = F.softmax(attn_weights, dim=-1)
            return activations, attn_weights
        return activations

layer = RoPEMaskedAttentionHead(config)
batch = torch.randn((config['batch_size'], config['context_window'], config['d_model']))
output, attn_weights = layer(batch, return_attn_weights=True)

# %%
layer = RoPEMaskedAttentionHead(MASTER_CONFIG)
batch = torch.ones((MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'], MASTER_CONFIG['d_model']))
output, attn_weights = layer(batch, return_attn_weights=True)

plt.imshow(attn_weights[0].detach().numpy())
plt.colorbar()

# %%
class RoPEMaskedMultiheadAttention(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        self.heads = nn.ModuleList([
            RoPEMaskedAttentionHead(config) for _ in range(config['n_heads'])
        ])
        self.linear = nn.Linear(config['n_heads'] * config['d_model'], config['d_model'])
        self.dropout = nn.Dropout(.1)

    def forward(self, x):
        heads = [h(x) for h in self.heads]
        x = torch.cat(heads, dim=-1)
        x = self.linear(x)
        x = self.dropout(x)
        return x

MASTER_CONFIG.update({
    'n_heads': 8,
})
layer = RoPEMultiheadAttention(MASTER_CONFIG)
batch = torch.ones((MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'], MASTER_CONFIG['d_model']))
output = layer(batch)
output.shape

# %%
class RopeModel(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config

        self.embedding = nn.Embedding(config['vocab_size'], config['d_model'])
        self.rms = RMSNorm((config['context_window'], config['d_model']))
        self.rope_attention = RoPEMaskedMultiheadAttention(config)

        self.linear = nn.Sequential(
            nn.Linear(config['d_model'], config['d_model']),
            nn.ReLU(),
        )

        self.last_linear = nn.Linear(config['d_model'], config['vocab_size'])

        print("model params:", sum([m.numel() for m in self.parameters()]))

    def forward(self, idx, targets=None):
        x = self.embedding(idx)

        # one block of attention
        x = self.rms(x) # rms pre-normalization
        x = x + self.rope_attention(x)

        x = self.rms(x) # rms pre-normalization
        x = x + self.linear(x)

        logits = self.last_linear(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, self.config['vocab_size']), targets.view(-1))
            return logits, loss

        else:
            return logits

model = RopeModel(MASTER_CONFIG)
xs, ys = get_batches(dataset, 'train', MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'])

logits, loss = model(xs, ys)
optimizer = torch.optim.Adam(model.parameters())
train(model, optimizer)

# %%
MASTER_CONFIG.update({
    "epochs": 5000,
    "log_interval": 10,
})
train(model, optimizer)

# %%
class SwiGLU(nn.Module):
    """
    Swish-Gated Linear Unit
    https://arxiv.org/pdf/2002.05202v1.pdf
    """
    def __init__(self, size):
        super().__init__()
        self.config = config
        self.linear_gate = nn.Linear(size, size)
        self.linear = nn.Linear(size, size)
        self.beta = torch.randn(1, requires_grad=True)

        self.beta = nn.Parameter(torch.ones(1))
        self.register_parameter("beta", self.beta)

    def forward(self, x):
        swish_gate = self.linear_gate(x) * torch.sigmoid(self.beta * self.linear_gate(x))
        out = swish_gate * self.linear(x)
        return out

# %%
class RopeModel(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config

        self.embedding = nn.Embedding(config['vocab_size'], config['d_model'])
        self.rms = RMSNorm((config['context_window'], config['d_model']))
        self.rope_attention = RoPEMaskedMultiheadAttention(config)

        self.linear = nn.Sequential(
            nn.Linear(config['d_model'], config['d_model']),
            SwiGLU(config['d_model']),
        )

        self.last_linear = nn.Linear(config['d_model'], config['vocab_size'])

        print("model params:", sum([m.numel() for m in self.parameters()]))

    def forward(self, idx, targets=None):
        x = self.embedding(idx)

        # one block of attention
        x = self.rms(x) # rms pre-normalization
        x = x + self.rope_attention(x)

        x = self.rms(x) # rms pre-normalization
        x = x + self.linear(x)

        logits = self.last_linear(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, self.config['vocab_size']), targets.view(-1))
            return logits, loss

        else:
            return logits

model = RopeModel(MASTER_CONFIG)
xs, ys = get_batches(dataset, 'train', MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'])

logits, loss = model(xs, ys)
optimizer = torch.optim.Adam(model.parameters())
train(model, optimizer)

# %%
# add RMSNorm and residual conncection
class LlamaBlock(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config

        self.rms = RMSNorm((config['context_window'], config['d_model']))

        self.attention = RoPEMaskedMultiheadAttention(config)
        self.feedforward = nn.Sequential(
            nn.Linear(config['d_model'], config['d_model']),
            SwiGLU(config['d_model']),
        )

    def forward(self, x):
        x = self.rms(x) # rms pre-normalization
        x = x + self.attention(x)

        x = self.rms(x) # rms pre-normalization
        x = x + self.feedforward(x)
        return x

# %%
block = LlamaBlock(MASTER_CONFIG)
block(torch.randn(MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'], MASTER_CONFIG['d_model']));

# %%
from collections import OrderedDict

MASTER_CONFIG.update({
    'n_layers': 4,
})
class Llama(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        self.embeddings = nn.Embedding(config['vocab_size'], config['d_model'])
        self.llama_blocks = nn.Sequential(
            OrderedDict([(f"llama_{i}", LlamaBlock(config)) for i in range(config['n_layers'])])
        )

        self.ffn = nn.Sequential(
            nn.Linear(config['d_model'], config['d_model']),
            SwiGLU(config['d_model']),
            nn.Linear(config['d_model'], config['vocab_size']),
        )

        print("model params:", sum([m.numel() for m in self.parameters()]))

    def forward(self, idx, targets=None):
        x = self.embeddings(idx)
        x = self.llama_blocks(x)
        logits = self.ffn(x)

        if targets is None:
            return logits

        else:
            loss = F.cross_entropy(logits.view(-1, self.config['vocab_size']), targets.view(-1))
            return logits, loss

llama = Llama(MASTER_CONFIG)
optimizer = torch.optim.Adam(llama.parameters())
train(llama, optimizer, config=MASTER_CONFIG)

# %%
MASTER_CONFIG.update({
    'epochs': 10000,
})
train(llama, optimizer, scheduler=None, config=MASTER_CONFIG)

# %%
train(llama, optimizer, config=MASTER_CONFIG)

# %%
print(generate(llama, MASTER_CONFIG, 500)[0])

# %%
xs, ys = get_batches(dataset, 'test', MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'])

logits, loss = llama(xs, ys)

print(loss)

# %%
# print the percentage that are near 0
def show_grads(model, tol=1e-2):
    return sorted([(name, 100.0 * float(torch.sum(torch.abs(param) <= tol)) / float(param.nelement())) for name, param in model.named_parameters() if param.requires_grad], key=lambda t: t[1], reverse=True)

show_grads(llama)

# %%
MASTER_CONFIG.update({
    "epochs": 1000
})
llama_with_cosine = Llama(MASTER_CONFIG)
llama_optimizer = torch.optim.Adam(
    llama.parameters(),
    betas=(.9, .95),
    weight_decay=.1,
    eps=1e-9,
    lr=1e-3
)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(llama_optimizer, 300, eta_min=1e-5)
train(llama_with_cosine, llama_optimizer, scheduler=scheduler)

# %%
show_grads(llama_with_cosine, 1e-5)
